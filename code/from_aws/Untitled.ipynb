# %%
import pandas as pd

# %%
blogs = pd.read_pickle('picked_dfs/blog_df_posts_categorized.pkl')

# %%
blogs.describe()
# Out:
#                  ID  subscribers_count   url_length  len_blog_name  \
# count  1.695000e+03        1695.000000  1695.000000    1695.000000
# mean   3.530204e+07         124.919764    13.735103      20.622419
# std    2.880042e+07         933.936571     4.854194      12.186817
# min    4.328100e+04           0.000000     2.000000       0.000000
# 25%    1.003008e+07           4.000000    10.000000      14.000000
# 50%    2.928603e+07          18.000000    13.000000      18.000000
# 75%    5.627471e+07          63.000000    17.000000      24.000000
# max    1.139077e+08       24069.000000    37.000000      95.000000
#
#        words_in_blog_name    num_posts  blog_life_in_days  average_gap  \
# count         1695.000000  1695.000000        1695.000000  1695.000000
# mean             3.163422   227.463717        1129.953982    13.071276
# std              2.086915   340.345034         903.847511    20.727648
# min              0.000000     5.000000           0.000000   -41.000000
# ...

# %%
from helpers import is_outlier
blogs = blogs[~is_outlier(blogs['subscribers_count'])]
blogs.describe()
# Out:
#                  ID  subscribers_count   url_length  len_blog_name  \
# count  1.429000e+03        1429.000000  1429.000000    1429.000000
# mean   3.516967e+07          22.983205    13.745276      20.961512
# std    2.941282e+07          26.834168     4.892062      12.577404
# min    4.328100e+04           0.000000     2.000000       0.000000
# 25%    9.521400e+06           3.000000    10.000000      14.000000
# 50%    2.829795e+07          11.000000    13.000000      18.000000
# 75%    5.651055e+07          35.000000    17.000000      25.000000
# max    1.139077e+08         112.000000    37.000000      95.000000
#
#        words_in_blog_name    num_posts  blog_life_in_days  average_gap  \
# count         1429.000000  1429.000000        1429.000000  1429.000000
# mean             3.180546   174.526942        1040.540938    14.560273
# std              2.075504   275.175748         860.393299    22.161934
# min              0.000000     5.000000           0.000000   -41.000000
# ...

# %%
blogs.single_topic_blog.value_counts()
# Out:
# False    1640
# True       55
# Name: single_topic_blog, dtype: int64

# %%
import
